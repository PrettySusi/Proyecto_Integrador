# %% [markdown]
# <a href="https://colab.research.google.com/github/PrettySusi/Proyecto_Integrador/blob/main/Entrega2_automatizaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerias

import pandas as pd
import kagglehub

# %%
# Descarga el dataset (devuelve la ruta local)
path = kagglehub.dataset_download("steve1215rogg/student-lifestyle-dataset")

# Carga el CSV manualmente
df_academica = pd.read_csv(path + "/student_lifestyle_dataset.csv")

df_academica.head()
# Out:
# Using Colab cache for faster access to the 'student-lifestyle-dataset' dataset.
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
# ...

# %%
# Descarga el dataset (devuelve la ruta local)
path = kagglehub.dataset_download("adilshamim8/social-media-addiction-vs-relationships")

# Carga el CSV manualmente
df_rsociales = pd.read_csv(path + "/Students Social Media Addiction.csv")

df_rsociales.head()
# Out:
# ...
# 100%|██████████| 7.67k/7.67k [00:00<00:00, 8.65MB/s]
# Extracting files...
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# ...
